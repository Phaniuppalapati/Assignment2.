# %%
Q1. In Python, a string is a type of data that represents a sequence of characters enclosed in quotation marks, either single (") or double ("'"'). Strings are used to store and manipulate textual data. For example:
name = "John Doe"
In the above code, "John Doe" is a string assigned to the variable `name`. Strings can contain letters, numbers, symbols, and spaces.
In Python, variables are created by assigning a value to them using the assignment operator (=). For example:
age = 25
In the code above, `age` is a variable that stores the value 25. Variables can hold various types of data, including strings, numbers, booleans, and more.In Python, a string is a type of data that represents a sequence of characters enclosed in quotation marks, either single (") or double ("'"'). Strings are used to store and manipulate textual data. For example:
name = "John Doe"
In the above code, "John Doe" is a string assigned to the variable `name`. Strings can contain letters, numbers, symbols, and spaces.
In Python, variables are created by assigning a value to them using the assignment operator (=). For example:
age = 25
In the code above, `age` is a variable that stores the value 25. Variables can hold various types of data, including strings, numbers, booleans, and more.


Q 2. In Python, a string is a type of data that represents a sequence of characters enclosed in quotation marks, either single (") or double ("'"'). Strings are used to store and manipulate textual data. For example:
name = "John Doe"
In the above code, "John Doe" is a string assigned to the variable `name`. Strings can contain letters, numbers, symbols, and spaces.
In Python, variables are created by assigning a value to them using the assignment operator (=). For example:
age = 25
In the code above, `age` is a variable that stores the value 25. Variables can hold various types of data, including strings, numbers, booleans, and more.
Q 3 
1. Integer (int):
An integer is a whole number without any decimal points. It can be positive, negative, or zero. For example: `0`, `-5`, `10. Integers are used for representing numerical values in various calculations and operations.
2. String (str):A string is a sequence of characters enclosed in single quotes (") or double quotes (""). It represents textual data and allows you to store and manipulate sequences of letters, numbers, symbols, and spaces. For example:

Hello, World!'`, `"Python"`.

Strings are used for handling text- based data and are often used for input/output operations, data manipulation, and text processing.

3. List:A list is an ordered collection of elements enclosed in square brackets ([]). It can contain elements of different data types, such as integers, strings, or even other lists. Lists are mutable, meaning their elements can be modified. For example: [1, 2, 3]`, `['apple', 'banana', 'orange']. Lists are commonly used for storing and organizing multiple items, and they provide various methods for adding, removing, and accessing elements.

Q 4 
In Python, an expression is a combination of values, variables, operators, and function calls that evaluates to a single value. It can be as simple as a single variable or value, or it can be more complex, involving multiple components and operations.

Expressions can include:

1)Literals: These are fixed values such as numbers (e.g., 42, 3.14) or strings (e.g., "Hello, world!").

2)Variables: These are names that represent values stored in memory. You can use variables in expressions to perform operations or retrieve values.

3)Operators: These are symbols that perform specific operations on one or more values. For example, arithmetic operators (+, -, *, /) perform mathematical calculations, and comparison operators (==, !=, >, <, >=, <=) compare values.

Function calls: These are invocations of predefined functions or user-defined functions. Functions can take arguments and return values, and you can use them within expressions.

Expressions in Python are used to compute values and perform operations. They can be used in assignments to assign values to variables, in conditional statements to control program flow, as arguments to functions, or as part of more complex expressions
Q 5
An expression is a piece of code that produces a value when it is executed. It can be a combination of variables, literals, operators, and function calls. Examples of expressions include:

2 + 3 (evaluates to the value 5)

x ^ * y* (evaluates the product of variables x and y)

len (^ prime prime heII o^ prime prime ) (evaluates to the length of the string "hello")

On the other hand, a statement is a complete unit of code that performs an action. It usually consists of one or more expressions and can include control flow structures such as conditionals and loops. Statements do not produce a value. Examples of statements include:

Assignment statement: `spam = 10 (assigns the value 10 to the variable `spam`)

 Print statement: print("Hello, world!") (prints the string "Hello, world!")

Want Conditional statement: if x >

5: ... (executes the indented block of code if the condition `x >
5 is true)


Q 6

After running the given code, the variable `bacon` would contain the value 22. The code `bacon + 1` does not update the value of 'bacon`, but instead performs addition using the current value of `bacon (which is 22) and the number 1. However, it does not assign the result of the addition back to the `bacon` variable. To update the value of `bacon`, you would need to assign the result back + 1' or using the shorthand operator:

to `bacon, like this: `bacon = bacon

*bacon += 1 ..
Q 7
1. 'spam' + 'spamspam': This term performs string concatenation. It combines the string 'spam' with the string 'spamspam', resulting in the value 'spamspamspamspam'. Therefore, the value of the term 'spam' + 'spam spam' is 'spam spam spam spam'.

2. 'spam'* 3: This term performs string repetition. It repeats the string 'spam' three times, resulting in the value 'spam spam spam'. Therefore, the value of the term 'spam' * 3 is 'spam spam spam'.

Q 8
In most programming languages, including popular ones like Python, eggs is a valid variable name because it follows the naming rules and conventions for variables. However, 100 is considered an invalid variable name in most programming languages.

Here are some general rules for naming variables:

1. Variables must start with a letter a - Z A-Z) or an underscore (_) character.

2. After the first character, variables can include letters, numbers, and underscores.
3. Variable names are case-sensitive, so "Eggs" and "eggs" would be considered different variables.

4. Variables should not be named after reserved keywords or built-in functions of the programming language.

Based on these rules, eggs meets the requirements for a valid variable name because it starts with a letter and contains only letters. On the other hand, 100 starts with a number, which violates the rule that variables must start with a letter or an underscore. However, it's worth noting that some programming languages have different naming conventions or allow
certain symbols in variable names, so the rules can vary depending on the language being used.
Q 9
1. `int()`: This function is used to convert a value into an integer. It can convert a floating-point number or a string representing a integer into an integer. However, if the value is a string representing a non-integer, it will raise a

`Value Error' exception.

Example usage:
value = 42.7 integer value = int(value) print(integer_value) # Output

2. float(): This function is used to

convert a value into a floating
2. `float(): This function is used to convert a value into a floating- point number. It can convert an integer or a string representing a number into a float. If the value is a string representing a non-numeric value, it will raise a `Value Error exception.

Example usage:
value="3.14"
float_value = float(value) print (float_value) # Output:

3. str(): This function is used to convert a value into a string. It can
convert any value, including integers, floating-point numbers, or other objects, into a string representation.

Example usage:
value =42
string_value = str(value)
print(string_value) # Output:

These functions provide a convenient way to convert values between different data types in Python.

Q 10

The expression ''I have eaten' +

99 + 'burritos.'` causes an error because you're trying to concatenate a string ('I have eaten'') with an integer (99). In many programming languages, including Python, you cannot directly concatenate different types of variables.

To fix this error, you can convert the integer `99 into a string before concatenating it with the other strings. Here's the corrected expression:
+ str(99) +'I have eaten
In this modified version, the ` str(99) ` converts the integer `99` into a string, allowing it to be concatenated with the other strings. The resulting expression will be `'I have eaten 99 burritos.'', which is the desired output.
